# %% [markdown]
# # gantt charts

# %% [markdown]
# <p style="line-height:30px"><b><font color="#999999" style="font-family:Arial; font-size:24px">fivecentplots.gantt(df, **kwargs)</font></b><br><b><i>Gantt chart plotting function.  This plot is built off of a horizontal implementation of `fcp.bar`.</i></b><br><br><b>Args:</b><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>df</b> (<i><font color="#0c9c6e">DataFrame</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;DataFrame containing data to plot<br><br><b>Required Keyword Args:</b><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>x</b> (<i><font color="#0c9c6e">list</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;two x-axis column names containing Datetime values 1) the start time for each item in the Gantt chart<br> 2) the stop time for each item in the Gantt chart<br>&nbsp;&nbsp;&nbsp;&nbsp;<b>y</b> (<i><font color="#0c9c6e">str</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;y-axis column name<br>&nbsp;&nbsp;&nbsp;&nbsp;<b>z</b> (<i><font color="#0c9c6e">str</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;z-axis column name<br><br><b>Optional Keyword Args:</b><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_color_by_bar | color_by_bar</b> (<i><font color="#0c9c6e">bool</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Color each Gantt bar differently. Defaults to False.<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Styling>See example</a><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_height | height</b> (<i><font color="#0c9c6e">float</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Set the fractional height of the Gantt bars between 0-1. Defaults to 0.9. <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Styling>See example</a><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_edge_color</b> (<i><font color="#0c9c6e">str</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hex color string for the edge of the Gantt bars. Defaults to fcp.DEFAULT_COLORS. <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Styling>See example</a><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_edge_width</b> (<i><font color="#0c9c6e">float</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Width of the edge of the Gantt bars in pixels. Defaults to 0.<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Styling>See example</a><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_order_by_legend | order by legend</b> (<i><font color="#0c9c6e">bool</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Order the y-axis values based on the sort order of the legend values [requires legend]. Defaults to False. <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Legends>See example</a><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_fill_alpha</b> (<i><font color="#0c9c6e">int</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Transparency value for the Gantt bars between 0-1. Defaults to 0.75.<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Styling>See example</a><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_fill_color</b> (<i><font color="#0c9c6e">str</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Hex color string of the Gantt bar fill . Defaults to fcp.DEFAULT_COLORS. <br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_label_x</b> (<i><font color="#0c9c6e">str</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;By default, x-axis labels are disabled for this plot type. Defaults to \'’. <br>&nbsp;&nbsp;&nbsp;&nbsp;<b>gantt_tick_labels_x_rotation | tick_labels_x_rotation</b> (<i><font color="#0c9c6e">int</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Gantt-specific version of the this kwarg to ensure rotations are not applied globably to all plots from a theme file.<br> Defaults to 90. <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Legends>See example</a><br>&nbsp;&nbsp;&nbsp;&nbsp;<b>sort</b> (<i><font color="#0c9c6e">str</font></i>):<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sort order for the Gantt bars {‘ascending’, ‘descending’}. Defaults to \'descending’. <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href=https://endangeredoxen.github.io/fivecentplots/0.5.0/gantt.html#Sorting>See example</a></p>

# %% [markdown]
# ## Setup

# %% [markdown]
# Import packages:

# %%
import fivecentplots as fcp
import pandas as pd
from pathlib import Path

# %% [markdown]
# Read some made-up Gantt chart data for the recording schedule of one of the greatest albums of one of the greatest bands:

# %%
df = pd.read_csv(Path(fcp.__file__).parent / 'tests/fake_data_gantt.csv')
df.head()
# Out:
#                    Task Assigned       Start        Stop   Category
# 0          Record drums   Taylor  2010-09-01  2010-09-05  Recording
# 1           Record bass     Nate  2010-09-04  2010-09-06  Recording
# 2  Record rhythm guitar      Pat  2010-09-06  2010-09-08  Recording
# 3  Record rhythm guitar     Dave  2010-09-06  2010-09-08  Recording
# 4    Record lead guitar    Chris  2010-09-07  2010-09-09  Recording

# %% [markdown]
# Optionally set the design theme (skipping here and using default):

# %%
#fcp.set_theme('gray')
#fcp.set_theme('white')

# %% [markdown]
# ## Basic chart

# %% [markdown]
# We create a basic Gantt chart showing tasks across a time axis specified by start and stop column containing `Datetime` values:

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', ax_size=[600, 400])

# %% [markdown]
# As with other plots, tick label fonts, sizes, and rotations can all be controlled using the correct ``kwarg``.  See <a href="ticks.html">Grids and ticks</a> for more details.

# %% [markdown]
# ## Grouping

# %% [markdown]
# Like all other plots in <b><i><font color="#4d5a91">fivecentplots </font></i></b>, Gantt charts can grouped in various ways to provide further insight into the data set.  This includes:
#
# * `legend`
# * `row`
# * `col`
# * `wrap`
#
# keyword options.  A couple of examples are shown below.

# %% [markdown]
# ### Legends

# %% [markdown]
# Legends can be used to further distinguish various tasks by assignee or other factors.  If the same task has multiple assignees, they will be split into two different bars in the chart.

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', legend='Assigned', ax_size=[600, 400], gantt_tick_labels_x_rotation=45)

# %% [markdown]
# When using a legend, we can also sort the y-axis values based on the order in the legend using keyword `order_by_legend=True`:

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', legend='Assigned', ax_size=[600, 400], gantt_tick_labels_x_rotation=45, order_by_legend=True)

# %% [markdown]
# ### Row/column plot

# %% [markdown]
# Row grouping (`share_y` is automatically disabled):

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', row='Category', ax_size=[400, 240])

# %% [markdown]
# Column grouping (`share_y` is automatically disabled):

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', col='Category', ax_size=[400, 240])

# %% [markdown]
# ### Wrap plot

# %% [markdown]
# Notice that `share_y` is enabled for this type of grouping:

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', wrap='Category', ax_size=[400, 240])

# %% [markdown]
# ## Styling

# %% [markdown]
# Default style:

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', ax_size=[600, 400])

# %% [markdown]
# Now with various style modifications:

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', ax_size=[600, 400], color_by_bar=True, 
          gantt_edge_width=2, gantt_edge_color='#555555', gantt_height=0.2, gantt_fill_alpha=1)

# %% [markdown]
# ## Sorting

# %% [markdown]
# By default, the sorting order of tasks is "descending" from top to bottom by date.  We can flip that behavior with the keyword `sort='ascending'`:

# %%
fcp.gantt(df, x=['Start', 'Stop'], y='Task', sort='ascending', ax_size=[600, 400])
