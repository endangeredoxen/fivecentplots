# %% [markdown]
# # boxplot() Examples

# %%
__author__    = 'Steve Nicholes'
__copyright__ = 'Copyright (C) 2018 Steve Nicholes'
__license__   = 'GPL v3'
__version__   = '0.3.0'

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path = [r'C:\GitHub\fivecentplots'] + sys.path
import fivecentplots as fcp
import pandas as pd
import numpy as np
import os, sys, pdb
osjoin = os.path.join
st = pdb.set_trace
fcp
# Out:
# <module 'fivecentplots' from 'C:\\GitHub\\fivecentplots\\fivecentplots\\__init__.py'>

# %% [markdown]
# ### Sample data

# %%
df = pd.read_csv(osjoin(os.path.dirname(fcp.__file__), 'tests', 'fake_data_box.csv'))

# %% [markdown]
# ### Set theme

# %%
#fcp.set_theme('gray')
#fcp.set_theme('white')

# %% [markdown]
# ### Other

# %%
SHOW = False

# %% [markdown]
# ## Groups

# %% [markdown]
# ### Single group

# %%
df.columns
# Out:
# Index(['Batch', 'Sample', 'Region', 'Value'], dtype='object')

# %%
fcp.boxplot(df=df, y='Value', groups=['Batch', 'Sample'],  filename='test', ax_size=[400, 250],
           box_connect_stat='mean', legend='Region', legend_edge_color='#000000')
# legend position still screwy on inline; moves with number of groups so the vertical spacing must be impacted by it
# Out:
# bah: axes[ia].get_xaxis().get_major_formatter().set_scientific(False)
# test.png
