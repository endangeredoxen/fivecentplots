# %% [markdown]
# # <b>hist</b>

# %% [markdown]
# The `hist` function allows histogram visualizing DataFrame data.  At a minimum, the `hist` function requires the following keywords:
# <ul>
# <li> `df`: a pandas DataFrame</li>
# <li> `y`: the name of the DataFrame column containing the y-axis data </li>
# </ul>
#
# Other optional keywords are described in <a href="https://endangeredoxen.github.io/fivecentplots/keyword.html">Keyword Arguments</a>.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import fivecentplots as fcp
import pandas as pd
import numpy as np
import os, sys, pdb
osjoin = os.path.join
st = pdb.set_trace

# %% [markdown]
# ### Sample data

# %%
df = pd.read_csv(osjoin(os.path.dirname(fcp.__file__), 'tests', 'fake_data_box.csv'))
df.head()
# Out:
#    Batch  Sample    Region  Value            ID
# 0    101       1  Alpha123    3.5     ID701223A
# 1    101       1  Alpha123    2.1  ID7700-1222B
# 2    101       1  Alpha123    3.3     ID701223A
# 3    101       1  Alpha123    3.2  ID7700-1222B
# 4    101       1  Alpha123    4.0     ID701223A

# %% [markdown]
# ### Set theme

# %% [markdown]
# (Only needs to be run once)

# %%
#fcp.set_theme('gray')
#fcp.set_theme('white')

# %% [markdown]
# ### Other

# %%
SHOW = False

# %% [markdown]
# ## Simple histogram

# %% [markdown]
# A simple histogram with default bin size of 20:

# %%
fcp.hist(df=df, y='Value', show=SHOW)
# ymax limit is wrong
# Out:
# Counts.png

# %% [markdown]
# ## Legend

# %% [markdown]
# Add a legend:

# %%
fcp.hist(df=df, y='Value', show=SHOW, legend='Region')
# ymax limit is wrong
# Out:
# Counts.png

# %% [markdown]
# ## Kernal density estimator

# %%
fcp.hist(df=df, y='Value', show=SHOW, legend='Region', kde=True, kde_width=2)
# not computing tick label width correctly
# Out:
# Normalized Counts.png

# %% [markdown]
# ## Row/column plot

# %% [markdown]
# Make multiple subplots with different row/column values:

# %%
fcp.hist(df=df, y='Value', show=SHOW, legend='Region', kde=True, kde_width=2, col='Batch', row='Sample')
# can we make the kde go the full range of the plot?
# check x and y range limits
# Out:
# Normalized Counts by Sample by Batch.png

# %% [markdown]
# ## Wrap plot

# %%
fcp.hist(df=df, y='Value', show=SHOW, legend='Region', kde=True, kde_width=2, wrap='Batch')
# same comment as above
# Out:
# Normalized Counts by Batch.png
