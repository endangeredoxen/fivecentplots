# %% [markdown]
# # Ticks

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import fivecentplots as fcp
import pandas as pd
import numpy as np
import seaborn as sns
import os, sys, pdb
osjoin = os.path.join
st = pdb.set_trace

# %% [markdown]
# ### Sample data

# %% [markdown]
# ### Set theme

# %% [markdown]
# Optionally set design theme

# %%
#fcp.set_theme('gray')
#fcp.set_theme('white')

# %% [markdown]
# ### Other

# %%
SHOW = False
