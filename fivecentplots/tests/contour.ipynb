# %% [markdown]
# # Contour plots

# %%
__author__    = 'Steve Nicholes'
__copyright__ = 'Copyright (C) 2018 Steve Nicholes'
__license__   = 'GPL v3'
__version__   = '0.3.0'

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path = [r'C:\GitHub\fivecentplots'] + sys.path
import fivecentplots as fcp
import pandas as pd
import numpy as np
import os, sys, pdb
osjoin = os.path.join
st = pdb.set_trace
fcp
# Out:
# <module 'fivecentplots' from 'C:\\GitHub\\fivecentplots\\fivecentplots\\__init__.py'>

# %% [markdown]
# ### Sample data

# %%
df = pd.read_csv(osjoin(os.path.dirname(fcp.__file__), 'tests', 'fake_data_contour.csv'))

# %% [markdown]
# ### Set theme

# %%
#fcp.set_theme('gray')
#fcp.set_theme('white')

# %% [markdown]
# ### Other

# %%
SHOW = False

# %% [markdown]
# ## Basic contour

# %%
fcp.contour(df=df, x='X', y='Y', z='Value', row='Batch', col='Experiment', filled=False,
            cbar=False, xmin=-3, xmax=3, ymin=-3, ymax=3, ax_size=[250,250], show=SHOW)
# Out:
# Value vs Y vs X by Batch by Experiment.png

# %% [markdown]
# ## Filled contour

# %%
fcp.contour(df=df, x='X', y='Y', z='Value', row='Batch', col='Experiment', filled=True,
            cbar=True, xmin=-3, xmax=3, ymin=-3, ymax=3, ax_size=[250,250], show=SHOW)
# Out:
# Value vs Y vs X by Batch by Experiment.png

# %% [markdown]
# ## Grid contours

# %%
0 --> 7
5 --> 14
10 --> 21
# Out:
#   File "<ipython-input-8-3b3607119dcd>", line 1
#     0 --> 7
#         ^
# SyntaxError: invalid syntax
