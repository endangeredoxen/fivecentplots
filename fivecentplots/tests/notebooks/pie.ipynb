# %% [markdown]
# # <b>pie<b>

# %% [markdown]
# <b><font color="blue" style="font-family:'Courier New'">fivecentplots </font></b> can plot pie charts using  `fcp.pie`.  At a minimum, the `bar` function requires the following keywords:
# <ul>
# <li> df: a pandas DataFrame</li>
# <li> x: the name of the categorical data column (i.e., the labels)
# <li> y: the name of the DataFrame column containing the values for the data in column x</li>
# </ul>

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import fivecentplots as fcp
import pandas as pd
import numpy as np
import os, sys, pdb
osjoin = os.path.join
db = pdb.set_trace

# %% [markdown]
# ### Sample data

# %% [markdown]
# Read some fake bar chart data

# %%
df = pd.read_csv(osjoin(os.path.dirname(fcp.__file__), 'tests', 'fake_data_bar.csv'))
df.loc[df.pH < 0, 'pH'] = -df.pH
df.head()
# Out:
#           Liquid   pH Measurement  T [C]
# 0    Lemon juice  2.4           A     25
# 1   Orange juice  3.5           A     25
# 2   Battery acid  1.0           A     25
# 3  Bottled water  6.7           A     25
# 4           Coke  3.0           A     25

# %% [markdown]
# ### Set theme

# %% [markdown]
# Optionally set the design theme

# %%
fcp.set_theme('gray')
#fcp.set_theme('white')
# Out:
# Previous theme file found! Renaming to "defaults_old.py" and copying new theme...done!

# %% [markdown]
# ### Other

# %%
SHOW = False

# %% [markdown]
# ## Basic Plot

# %% [markdown]
# Consider a DataFrame that contains several sets of measured pH data for various liquids.  First we plot only one set of measured data:

# %%
fcp.pie(df, x='Liquid', y='pH', show=SHOW, filter='Measurement=="A" & T [C]==25', shadow=False, startangle=90, alpha=0.85)

# %% [markdown]
# ## Donut

# %% [markdown]
# We can turn our pie chart into a donut chart by using the keyword `innerradius` (aka the `width` attribute in MPL's `wedgeprops`).  The inner radius should be lower than the main `radius` parameter (set to 1 by default).  In this example, we also shift the position of the percentages slightly to look cleaner.

# %%
fcp.pie(df, x='Liquid', y='pH', show=True, filter='Measurement=="A" & T [C]==25', shadow=False, startangle=90, alpha=0.85, innerradius=0.5, pctdistance=0.75)

# %% [markdown]
# ## Grouping

# %% [markdown]
# Like the <font style="font-family:'Courier New'">plot</font> function, pie charts can grouped in various ways to provide further insight into the data set.  This includes `row` and/or `col` subplot values and `wrap` values.  <b>Note:</b> legends are not currently supported (or needed?) for pie charts.

# %% [markdown]
# ### Row/column plot

# %% [markdown]
# We can separate different conditions using row/col plots as shown below:

# %%
fcp.pie(df, x='Liquid', y='pH', show=True, col='Measurement', row='T [C]', ax_size=[400, 400])

# %% [markdown]
# ### Wrap plot

# %% [markdown]
# Alternatively, we can use a `wrap` plot to visualize:

# %%
fcp.pie(df, x='Liquid', y='pH', show=SHOW, tick_labels_major_x_rotation=90, wrap='Measurement', ax_size=[300, 300])
