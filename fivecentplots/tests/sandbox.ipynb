# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
import pdb
import numpy as np
st = pdb.set_trace
import sys
sys.path = [r'C:\Github\fileio'] + sys.path
import fileio

# %%
file = r'C:\GitHub\fivecentplots\fivecentplots\doc\keywords.xlsx'

# %%
df = pd.read_excel(file)

# %%
df
# Out:
#     Element        Keyword Description     Default           Example
# 0   element            on?        blah           d  https://test.org
# 1       NaN            dpi        blah         100  https://test.org
# 2       NaN     fill_alpha        blah           1  https://test.org
# 3       NaN     fill_color        blah     #ffffff  https://test.org
# 4       NaN     edge_width        blah           1  https://test.org
# 5       NaN     edge_alpha        blah           1  https://test.org
# 6       NaN     edge_color        blah     #ffffff  https://test.org
# 7       NaN           font        blah  sans-serif  https://test.org
# 8       NaN     font_color        blah     #000000  https://test.org
# 9       NaN      font_size        blah          14  https://test.org
# 10      NaN     font_style        blah      normal  https://test.org
# 11      NaN    font_weight        blah      normal  https://test.org
# 12      NaN          alpha        blah           1  https://test.org
# 13      NaN          color        blah     #000000  https://test.org
# 14      NaN          width        blah           1  https://test.org
# 15      NaN          style        blah           -  https://test.org
# 16      fig            dpi        blah         100  https://test.org
# 17       ax        ax_size        blah  [400, 400]  https://test.org
# 18      NaN  ax_edge_color        blah     #aaaaaa  https://test.org
# 19      NaN  ax_fill_color        blah     #eaeaea  https://test.org
# 20      NaN     ax_primary        blah           1  https://test.org
# 21      NaN       ax_scale        blah        None  https://test.org
# 22      NaN          sci_x        blah       False  https://test.org
# 23      NaN          sci_x        blah       False  https://test.org
# 24      NaN        share_x        blah        True  https://test.org
# 25      NaN        share_y        blah        True  https://test.org
# 26      NaN        share_z        blah        True  https://test.org
# 27      NaN       share_x2        blah        True  https://test.org
# 28      NaN       share_y2        blah        True  https://test.org
# 29      NaN      share_col        blah       False  https://test.org
# 30      NaN      share_row        blah       False  https://test.org
# 31      NaN          twinx        blah       False  https://test.org
# 32      NaN          twiny        blah       False  https://test.org
# 33      NaN           xmax        blah        None  https://test.org
# 34      NaN           xmin        blah        None  https://test.org
# 35      NaN           ymax        blah        None  https://test.org
# 36      NaN           ymin        blah        None  https://test.org
# 37      NaN           zmax        blah        None  https://test.org
# 38      NaN           zmin        blah        None  https://test.org
# 39      ax2          scale        blah      linear  https://test.org
# 40      NaN          x2max        blah        None  https://test.org
# 41      NaN          x2min        blah        None  https://test.org
# 42      NaN          y2max        blah        None  https://test.org
# 43      NaN          y2min        blah        None  https://test.org

# %%
width = pd.DataFrame(columns=df.columns, index=[0])
for col in df.columns:
    width[col] = max(df[col].apply(lambda x: len(str(x))).max(), len(col)) + 2
width
# Out:
#    Element  Keyword  Description  Default  Example
# 0        9       15           13       12       18

# %%
line = ''
for col in width.columns:
    line += '+' + '-'*width[col].iloc[0]
line += '+\n'

# %%
tab = ''
for irow, row in df.iterrows():
    for col, value in row.items():
        tab += (('| %s ' % value).ljust(width[col].iloc[0]+1)).replace('nan', '   ')
    tab += '|\n'
    # check for vertical merged
    line0 = ('%s' % line).split('+')
    if irow < len(df) - 1:
        nrow = df.iloc[irow+1]
        for icol, (col, value) in enumerate(nrow.items()):
            if type(value) is float and np.isnan(value):
                line0[icol+1] = line0[icol+1].replace('-', ' ')
    line0 = '+'.join(line0)
    tab += line0
print(tab)
# Out:
# | element | on?           | blah        | d          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | dpi           | blah        | 100        | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | fill_alpha    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | fill_color    | blah        | #ffffff    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | edge_width    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | edge_alpha    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | edge_color    | blah        | #ffffff    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font          | blah        | sans-serif | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_color    | blah        | #000000    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_size     | blah        | 14         | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_style    | blah        | normal     | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_weight   | blah        | normal     | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | alpha         | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | color         | blah        | #000000    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | width         | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | style         | blah        | -          | https://test.org |
# +---------+---------------+-------------+------------+------------------+
# | fig     | dpi           | blah        | 100        | https://test.org |
# +---------+---------------+-------------+------------+------------------+
# | ax      | ax_size       | blah        | [400, 400] | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_edge_color | blah        | #aaaaaa    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_fill_color | blah        | #eaeaea    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_primary    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_scale      | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | sci_x         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | sci_x         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_x       | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_y       | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_z       | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_x2      | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_y2      | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_col     | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_row     | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | twinx         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | twiny         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | xmax          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | xmin          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ymax          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ymin          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | zmax          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | zmin          | blah        | None       | https://test.org |
# +---------+---------------+-------------+------------+------------------+
# | ax2     | scale         | blah        | linear     | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | x2max         | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | x2min         | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | y2max         | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | y2min         | blah        | None       | https://test.org |
# +---------+---------------+-------------+------------+------------------+

# %%
header = line
for col in df.columns:
    header += ('| %s ' % col).ljust(width[col].iloc[0]+1)
header += '|\n'
header += line.replace('-', '=')
print(header)
# Out:
# +---------+---------------+-------------+------------+------------------+
# | Element | Keyword       | Description | Default    | Example          |
# +=========+===============+=============+============+==================+

# %%
print(header + tab)
# Out:
# +---------+---------------+-------------+------------+------------------+
# | Element | Keyword      | Description | Default   | Example          |
# +=========+===============+=============+============+==================+
# | element | on?           | blah        | d          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | dpi           | blah        | 100        | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | fill_alpha    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | fill_color    | blah        | #ffffff    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | edge_width    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | edge_alpha    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | edge_color    | blah        | #ffffff    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font          | blah        | sans-serif | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_color    | blah        | #000000    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_size     | blah        | 14         | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_style    | blah        | normal     | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | font_weight   | blah        | normal     | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | alpha         | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | color         | blah        | #000000    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | width         | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | style         | blah        | -          | https://test.org |
# +---------+---------------+-------------+------------+------------------+
# | fig     | dpi           | blah        | 100        | https://test.org |
# +---------+---------------+-------------+------------+------------------+
# | ax      | ax_size       | blah        | [400, 400] | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_edge_color | blah        | #aaaaaa    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_fill_color | blah        | #eaeaea    | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_primary    | blah        | 1          | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ax_scale      | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | sci_x         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | sci_x         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_x       | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_y       | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_z       | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_x2      | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_y2      | blah        | True       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_col     | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | share_row     | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | twinx         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | twiny         | blah        | False      | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | xmax          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | xmin          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ymax          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | ymin          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | zmax          | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | zmin          | blah        | None       | https://test.org |
# +---------+---------------+-------------+------------+------------------+
# | ax2     | scale         | blah        | linear     | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | x2max         | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | x2min         | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | y2max         | blah        | None       | https://test.org |
# +         +---------------+-------------+------------+------------------+
# |         | y2min         | blah        | None       | https://test.org |
# +---------+---------------+-------------+------------+------------------+

# %%
print(fileio.utilities.xls_2_rst(file, 'Axes'))
# Out:
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | Keyword       | Data Type    | Description                                                                             | Default    | Example                                         |
# +===============+==============+=========================================================================================+============+=================================================+
# | size          | list of ints | width, height of plot area                                                              | [400, 400] | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | ax_edge_color | str          | outer edge color of plot area                                                           | #aaaaaa    | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | ax_fill_color | str          | inner fill color of plot area                                                           | #eaeaea    | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+            +-------------------------------------------------+
# | ax_scale      | str          | enable linear vs log scaling of axis                                                    |            | `log scale plot <plot.html#Log-scale>`_         |
# +               +              +-----------------------------------------------------------------------------------------+            +                                                 +
# |               |              | x-axis: ['linear', 'logx', 'semilogx']                                                  |            |                                                 |
# +               +              +-----------------------------------------------------------------------------------------+            +                                                 +
# |               |              | y-axis: ['linear', 'logx', 'semilogx']                                                  |            |                                                 |
# +               +              +-----------------------------------------------------------------------------------------+            +                                                 +
# |               |              | both: ['loglog', 'log']                                                                 |            |                                                 |
# +               +              +-----------------------------------------------------------------------------------------+            +                                                 +
# |               |              | other: ['symlog', 'logit']                                                              |            |                                                 |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | share_x       | boolean      | enable/disable primary x-axis range sharing across all subplots                         | True       | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | share_y       | boolean      | enable/disable primary y-axis range sharing across all subplots                         | True       | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | share_z       | boolean      | enable/disable primary z-axis range sharing across all subplots                         | True       | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | share_x2      | boolean      | enable/disable secondary x-axis range sharing across all subplots                       | True       | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | share_y2      | boolean      | enable/disable secondary y-axis range sharing across all subplots                       | True       | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | share_col     | boolean      | enable/disable axis range sharing for all subplots in a column of subplots              | False      | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | share_row     | boolean      | enable/disable axis range sharing for all subplots in a row of subplots                 | False      | None                                            |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | twin_x        | boolean      | enable/disable a secondary y-axis (x-axis is "twinned" or duplicated across two y-axes) | False      | `twin_x plot <plot.html#Shared-x-axis-twin_x>`_ |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+
# | twin_y        | boolean      | enable/disable a secondary x-axis (y-axis is "twinned" or duplicated across two x-axes) | False      | `twin_y plot <plot.html#Shared-y-axis-twin_y>`_ |
# +               +              +-----------------------------------------------------------------------------------------+            +                                                 +
# |               |              | Note:  wrap plots cannot be used when ``twin_y == True``                                |            |                                                 |
# +---------------+--------------+-----------------------------------------------------------------------------------------+------------+-------------------------------------------------+

# %%
# %time fcp.plot(df=df, x='Voltage', y='I [A]', legend='Die', inline=True, show=True, \
              filter='Substrate=="Si" & Target Wavelength==450 & Boost Level==0.2 & Temperature [C]==25',\
              wrap='Substrate', ax_size=[300, 300],  \
              rc_label_fill_color='#fffd75', rc_label_fill_alpha=0.5,\
              rc_label_font_color='#000000', wrap_title_fill_color='#00FFFF', \
              wrap_title_font_color='#000000', label_fill_color='#FF0000', label_fill_alpha=0.5)
